# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
import re
from sqlalchemy import create_engine
import nltk
nltk.download(['punkt', 'wordnet'])

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
import pickle
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# load data from database
engine = create_engine('sqlite:///cleaned_data_etl.db')
df = pd.read_sql_table('disaster_data', engine)

# %%
df.describe()
# Out:
#                 id       related       request         offer   aid_related  \
# count  26216.00000  26216.000000  26216.000000  26216.000000  26216.000000
# mean   15224.82133      0.773650      0.170659      0.004501      0.414251
# std     8826.88914      0.435276      0.376218      0.066940      0.492602
# min        2.00000      0.000000      0.000000      0.000000      0.000000
# 25%     7446.75000      1.000000      0.000000      0.000000      0.000000
# 50%    15662.50000      1.000000      0.000000      0.000000      0.000000
# 75%    22924.25000      1.000000      0.000000      0.000000      1.000000
# max    30265.00000      2.000000      1.000000      1.000000      1.000000
#
#        medical_help  medical_products  search_and_rescue      security  \
# count  26216.000000      26216.000000       26216.000000  26216.000000
# mean       0.079493          0.050084           0.027617      0.017966
# std        0.270513          0.218122           0.163875      0.132831
# min        0.000000          0.000000           0.000000      0.000000
# 25%        0.000000          0.000000           0.000000      0.000000
# 50%        0.000000          0.000000           0.000000      0.000000
# 75%        0.000000          0.000000           0.000000      0.000000
# max        1.000000          1.000000           1.000000      1.000000
#
#            military  child_alone         water          food       shelter  \
# count  26216.000000      26216.0  26216.000000  26216.000000  26216.000000
# mean       0.032804          0.0      0.063778      0.111497      0.088267
# std        0.178128          0.0      0.244361      0.314752      0.283688
# min        0.000000          0.0      0.000000      0.000000      0.000000
# 25%        0.000000          0.0      0.000000      0.000000      0.000000
# 50%        0.000000          0.0      0.000000      0.000000      0.000000
# 75%        0.000000          0.0      0.000000      0.000000      0.000000
# max        1.000000          0.0      1.000000      1.000000      1.000000
#
#            clothing         money  missing_people      refugees         death  \
# count  26216.000000  26216.000000    26216.000000  26216.000000  26216.000000
# mean       0.015449      0.023039        0.011367      0.033377      0.045545
# std        0.123331      0.150031        0.106011      0.179621      0.208500
# min        0.000000      0.000000        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000        0.000000      0.000000      0.000000
# max        1.000000      1.000000        1.000000      1.000000      1.000000
#
#           other_aid  infrastructure_related     transport     buildings  \
# count  26216.000000            26216.000000  26216.000000  26216.000000
# mean       0.131446                0.065037      0.045812      0.050847
# std        0.337894                0.246595      0.209081      0.219689
# min        0.000000                0.000000      0.000000      0.000000
# 25%        0.000000                0.000000      0.000000      0.000000
# 50%        0.000000                0.000000      0.000000      0.000000
# 75%        0.000000                0.000000      0.000000      0.000000
# max        1.000000                1.000000      1.000000      1.000000
#
#         electricity         tools     hospitals         shops   aid_centers  \
# count  26216.000000  26216.000000  26216.000000  26216.000000  26216.000000
# mean       0.020293      0.006065      0.010795      0.004577      0.011787
# std        0.141003      0.077643      0.103338      0.067502      0.107927
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        other_infrastructure  weather_related        floods         storm  \
# count          26216.000000     26216.000000  26216.000000  26216.000000
# mean               0.043904         0.278341      0.082202      0.093187
# std                0.204887         0.448191      0.274677      0.290700
# min                0.000000         0.000000      0.000000      0.000000
# 25%                0.000000         0.000000      0.000000      0.000000
# 50%                0.000000         0.000000      0.000000      0.000000
# 75%                0.000000         1.000000      0.000000      0.000000
# max                1.000000         1.000000      1.000000      1.000000
#
#                fire    earthquake          cold  other_weather  direct_report
# count  26216.000000  26216.000000  26216.000000   26216.000000   26216.000000
# mean       0.010757      0.093645      0.020217       0.052487       0.193584
# std        0.103158      0.291340      0.140743       0.223011       0.395114
# min        0.000000      0.000000      0.000000       0.000000       0.000000
# 25%        0.000000      0.000000      0.000000       0.000000       0.000000
# 50%        0.000000      0.000000      0.000000       0.000000       0.000000
# 75%        0.000000      0.000000      0.000000       0.000000       0.000000
# max        1.000000      1.000000      1.000000       1.000000       1.000000

# %%
# There is 2 in the related column so we will replace it with 1
df['related'] = df['related'].replace(2,1)

# %%
X = df.message
y = df[df.columns[4:]]
category_names = y.columns

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vec_count', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('mo_clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vec_count', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         ...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = pipeline.predict(X_test)

for i in range(36):
    print(y_test.columns[i], ':')
    print(classification_report(y_test.iloc[:,i], y_pred[:,i], target_names=category_names), '---')
# Out:
# related :
#                         precision    recall  f1-score   support
#
#                related       0.62      0.35      0.44      1527
#                request       0.82      0.94      0.88      5027
#
#            avg / total       0.78      0.80      0.78      6554
#  ---
# request :
#                         precision    recall  f1-score   support
#
#                related       0.88      0.99      0.93      5416
#                request       0.84      0.35      0.50      1138
#
#            avg / total       0.87      0.88      0.85      6554
#  ---
# offer :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      6531
#                request       0.00      0.00      0.00        23
#
#            avg / total       0.99      1.00      0.99      6554
#  ---
# aid_related :
#                         precision    recall  f1-score   support
#
#                related       0.72      0.89      0.80      3809
#                request       0.77      0.53      0.63      2745
#
#            avg / total       0.74      0.74      0.73      6554
#  ---
# medical_help :
#                         precision    recall  f1-score   support
#
#                related       0.92      1.00      0.96      6029
#                request       0.56      0.07      0.12       525
#
#            avg / total       0.90      0.92      0.89      6554
#  ---
# medical_products :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.97      6219
#                request       0.74      0.07      0.13       335
#
#            avg / total       0.94      0.95      0.93      6554
#  ---
# search_and_rescue :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      6349
#                request       0.47      0.03      0.06       205
#
#            avg / total       0.95      0.97      0.96      6554
#  ---
# security :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6437
#                request       0.50      0.01      0.02       117
#
#            avg / total       0.97      0.98      0.97      6554
#  ---
# military :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      6343
#                request       0.53      0.09      0.15       211
#
#            avg / total       0.96      0.97      0.96      6554
#  ---
# child_alone :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      6554
#
#            avg / total       1.00      1.00      1.00      6554
#  ---
# water :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.97      6136
#                request       0.89      0.19      0.31       418
#
#            avg / total       0.94      0.95      0.93      6554
#  ---
# food :
#                         precision    recall  f1-score   support
#
#                related       0.93      0.99      0.96      5826
#                request       0.86      0.42      0.57       728
#
#            avg / total       0.92      0.93      0.92      6554
#  ---
# shelter :
#                         precision    recall  f1-score   support
#
#                related       0.93      0.99      0.96      5971
#                request       0.74      0.17      0.28       583
#
#            avg / total       0.91      0.92      0.90      6554
#  ---
# clothing :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6452
#                request       0.88      0.07      0.13       102
#
#            avg / total       0.98      0.99      0.98      6554
#  ---
# money :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6390
#                request       0.86      0.04      0.07       164
#
#            avg / total       0.97      0.98      0.96      6554
#  ---
# missing_people :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6476
#                request       0.00      0.00      0.00        78
#
#            avg / total       0.98      0.99      0.98      6554
#  ---
# refugees :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      6339
#                request       0.92      0.06      0.11       215
#
#            avg / total       0.97      0.97      0.96      6554
#  ---
# death :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.98      6226
#                request       0.81      0.11      0.19       328
#
#            avg / total       0.95      0.95      0.94      6554
#  ---
# other_aid :
#                         precision    recall  f1-score   support
#
#                related       0.87      1.00      0.93      5676
#                request       0.54      0.03      0.06       878
#
#            avg / total       0.82      0.87      0.81      6554
#  ---
# infrastructure_related :
#                         precision    recall  f1-score   support
#
#                related       0.94      1.00      0.97      6133
#                request       0.17      0.00      0.00       421
#
#            avg / total       0.89      0.94      0.90      6554
#  ---
# transport :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.98      6229
#                request       0.82      0.08      0.15       325
#
#            avg / total       0.95      0.95      0.94      6554
#  ---
# buildings :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.98      6225
#                request       0.79      0.09      0.17       329
#
#            avg / total       0.95      0.95      0.94      6554
#  ---
# electricity :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6426
#                request       0.64      0.05      0.10       128
#
#            avg / total       0.97      0.98      0.97      6554
#  ---
# tools :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      6514
#                request       0.00      0.00      0.00        40
#
#            avg / total       0.99      0.99      0.99      6554
#  ---
# hospitals :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6477
#                request       0.00      0.00      0.00        77
#
#            avg / total       0.98      0.99      0.98      6554
#  ---
# shops :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      6518
#                request       0.00      0.00      0.00        36
#
#            avg / total       0.99      0.99      0.99      6554
#  ---
# aid_centers :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6477
#                request       0.00      0.00      0.00        77
#
#            avg / total       0.98      0.99      0.98      6554
#  ---
# other_infrastructure :
#                         precision    recall  f1-score   support
#
#                related       0.96      1.00      0.98      6284
#                request       0.40      0.01      0.01       270
#
#            avg / total       0.94      0.96      0.94      6554
#  ---
# weather_related :
#                         precision    recall  f1-score   support
#
#                related       0.84      0.96      0.90      4690
#                request       0.85      0.54      0.66      1864
#
#            avg / total       0.84      0.84      0.83      6554
#  ---
# floods :
#                         precision    recall  f1-score   support
#
#                related       0.93      1.00      0.96      5984
#                request       0.92      0.16      0.27       570
#
#            avg / total       0.93      0.93      0.90      6554
#  ---
# storm :
#                         precision    recall  f1-score   support
#
#                related       0.94      0.99      0.96      5955
#                request       0.77      0.33      0.47       599
#
#            avg / total       0.92      0.93      0.92      6554
#  ---
# fire :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      6504
#                request       0.50      0.04      0.07        50
#
#            avg / total       0.99      0.99      0.99      6554
#  ---
# earthquake :
#                         precision    recall  f1-score   support
#
#                related       0.96      0.99      0.98      5911
#                request       0.90      0.63      0.74       643
#
#            avg / total       0.96      0.96      0.95      6554
#  ---
# cold :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6423
#                request       0.75      0.09      0.16       131
#
#            avg / total       0.98      0.98      0.97      6554
#  ---
# other_weather :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.97      6230
#                request       0.58      0.02      0.04       324
#
#            avg / total       0.93      0.95      0.93      6554
#  ---
# direct_report :
#                         precision    recall  f1-score   support
#
#                related       0.85      0.98      0.91      5254
#                request       0.78      0.28      0.41      1300
#
#            avg / total       0.83      0.84      0.81      6554
#  ---
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 2, does not match size of target_names, 36
#   .format(len(labels), len(target_names))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 1, does not match size of target_names, 36
#   .format(len(labels), len(target_names))

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vec_count',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#            dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=1,
#            ngram_range=(1, 1), preprocessor=None, stop_words=None,
#            strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#            tokenizer=<function tokenize at 0x7fe6853b9d90>, vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('mo_clf',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                max_depth=None, max_features='auto', max_leaf_nodes=None,
#                min_impurity_decrease=0.0, min_impurity_split=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#                oob_score=False, random_state=None, verbose=0,
#                warm_start=False),
#               n_jobs=1))],
#  'vec_count': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#          dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#          lowercase=True, max_df=1.0, max_features=None, min_df=1,
#          ngram_range=(1, 1), preprocessor=None, stop_words=None,
#          strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#          tokenizer=<function tokenize at 0x7fe6853b9d90>, vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'mo_clf': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#             n_jobs=1),
#  'vec_count__analyzer': 'word',
#  'vec_count__binary': False,
#  'vec_count__decode_error': 'strict',
#  'vec_count__dtype': numpy.int64,
#  'vec_count__encoding': 'utf-8',
#  'vec_count__input': 'content',
#  'vec_count__lowercase': True,
#  'vec_count__max_df': 1.0,
#  'vec_count__max_features': None,
#  'vec_count__min_df': 1,
#  'vec_count__ngram_range': (1, 1),
#  'vec_count__preprocessor': None,
#  'vec_count__stop_words': None,
#  'vec_count__strip_accents': None,
#  'vec_count__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vec_count__tokenizer': <function __main__.tokenize(text)>,
#  'vec_count__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'mo_clf__estimator__bootstrap': True,
#  'mo_clf__estimator__class_weight': None,
#  'mo_clf__estimator__criterion': 'gini',
#  'mo_clf__estimator__max_depth': None,
#  'mo_clf__estimator__max_features': 'auto',
#  'mo_clf__estimator__max_leaf_nodes': None,
#  'mo_clf__estimator__min_impurity_decrease': 0.0,
#  'mo_clf__estimator__min_impurity_split': None,
#  'mo_clf__estimator__min_samples_leaf': 1,
#  'mo_clf__estimator__min_samples_split': 2,
#  'mo_clf__estimator__min_weight_fraction_leaf': 0.0,
#  'mo_clf__estimator__n_estimators': 10,
#  'mo_clf__estimator__n_jobs': 1,
#  'mo_clf__estimator__oob_score': False,
#  'mo_clf__estimator__random_state': None,
#  'mo_clf__estimator__verbose': 0,
#  'mo_clf__estimator__warm_start': False,
#  'mo_clf__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'mo_clf__n_jobs': 1}

# %%
parameters = {'mo_clf__estimator__min_samples_split': [2, 3, 4],
              'mo_clf__estimator__n_estimators': [10, 20, 40]}


cv = GridSearchCV(pipeline, param_grid=parameters, scoring='f1_micro',  n_jobs=2, verbose=2)

# %%
cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=10
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=10, total= 1.4min
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=10, total= 1.4min
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=10, total= 1.4min
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=20, total= 2.4min
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=20, total= 2.4min
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=20, total= 2.4min
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=40, total= 4.4min
# [CV] mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=40, total= 4.4min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=10, total= 1.3min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=10, total= 1.3min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=2, mo_clf__estimator__n_estimators=40, total= 4.6min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=10, total= 1.3min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=20, total= 2.3min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=20, total= 2.3min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=20, total= 2.4min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=40, total= 4.3min
# [CV] mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=40, total= 4.3min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=10, total= 1.2min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=3, mo_clf__estimator__n_estimators=40, total= 4.3min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=10
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=10, total= 1.2min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=10, total= 1.3min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=20, total= 2.2min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=20
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=20, total= 2.3min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=20, total= 2.3min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=40, total= 4.2min
# [CV] mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=40
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=40, total= 4.2min
# [CV]  mo_clf__estimator__min_samples_split=4, mo_clf__estimator__n_estimators=40, total= 2.7min
# [Parallel(n_jobs=2)]: Done  27 out of  27 | elapsed: 41.2min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('vec_count', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         ...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))]),
#        fit_params=None, iid=True, n_jobs=2,
#        param_grid={'mo_clf__estimator__min_samples_split': [2, 3, 4], 'mo_clf__estimator__n_estimators': [10, 20, 40]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='f1_micro', verbose=2)

# %%
cv.grid_scores_
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.56750, std: 0.00359, params: {'mo_clf__estimator__min_samples_split': 2, 'mo_clf__estimator__n_estimators': 10},
#  mean: 0.59100, std: 0.00274, params: {'mo_clf__estimator__min_samples_split': 2, 'mo_clf__estimator__n_estimators': 20},
#  mean: 0.60084, std: 0.00289, params: {'mo_clf__estimator__min_samples_split': 2, 'mo_clf__estimator__n_estimators': 40},
#  mean: 0.59200, std: 0.00656, params: {'mo_clf__estimator__min_samples_split': 3, 'mo_clf__estimator__n_estimators': 10},
#  mean: 0.60650, std: 0.00191, params: {'mo_clf__estimator__min_samples_split': 3, 'mo_clf__estimator__n_estimators': 20},
#  mean: 0.61007, std: 0.00239, params: {'mo_clf__estimator__min_samples_split': 3, 'mo_clf__estimator__n_estimators': 40},
#  mean: 0.59766, std: 0.00598, params: {'mo_clf__estimator__min_samples_split': 4, 'mo_clf__estimator__n_estimators': 10},
#  mean: 0.60664, std: 0.00352, params: {'mo_clf__estimator__min_samples_split': 4, 'mo_clf__estimator__n_estimators': 20},
#  mean: 0.60944, std: 0.00231, params: {'mo_clf__estimator__min_samples_split': 4, 'mo_clf__estimator__n_estimators': 40}]

# %%
cv.best_params_
# Out:
# {'mo_clf__estimator__min_samples_split': 3,
#  'mo_clf__estimator__n_estimators': 40}

# %%
# New model
new_model = cv.best_estimator_
print (cv.best_estimator_)
# Out:
# Pipeline(memory=None,
#      steps=[('vec_count', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         ...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
y_pred = new_model.predict(X_test)

for i in range(36):
    print(y_test.columns[i], ':')
    print(classification_report(y_test.iloc[:,i], y_pred[:,i], target_names=category_names), '---')
# Out:
# related :
#                         precision    recall  f1-score   support
#
#                related       0.72      0.26      0.38      1527
#                request       0.81      0.97      0.88      5027
#
#            avg / total       0.79      0.80      0.77      6554
#  ---
# request :
#                         precision    recall  f1-score   support
#
#                related       0.89      0.99      0.94      5416
#                request       0.90      0.43      0.58      1138
#
#            avg / total       0.89      0.89      0.88      6554
#  ---
# offer :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      6531
#                request       0.00      0.00      0.00        23
#
#            avg / total       0.99      1.00      0.99      6554
#  ---
# aid_related :
#                         precision    recall  f1-score   support
#
#                related       0.75      0.88      0.81      3809
#                request       0.78      0.60      0.68      2745
#
#            avg / total       0.76      0.76      0.76      6554
#  ---
# medical_help :
#                         precision    recall  f1-score   support
#
#                related       0.92      1.00      0.96      6029
#                request       0.62      0.06      0.11       525
#
#            avg / total       0.90      0.92      0.89      6554
#  ---
# medical_products :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.98      6219
#                request       0.87      0.08      0.15       335
#
#            avg / total       0.95      0.95      0.93      6554
#  ---
# search_and_rescue :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      6349
#                request       0.64      0.03      0.06       205
#
#            avg / total       0.96      0.97      0.96      6554
#  ---
# security :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6437
#                request       0.33      0.01      0.02       117
#
#            avg / total       0.97      0.98      0.97      6554
#  ---
# military :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      6343
#                request       0.67      0.08      0.14       211
#
#            avg / total       0.96      0.97      0.96      6554
#  ---
# child_alone :
#                         precision    recall  f1-score   support
#
#                related       1.00      1.00      1.00      6554
#
#            avg / total       1.00      1.00      1.00      6554
#  ---
# water :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.97      6136
#                request       0.91      0.27      0.42       418
#
#            avg / total       0.95      0.95      0.94      6554
#  ---
# food :
#                         precision    recall  f1-score   support
#
#                related       0.93      0.99      0.96      5826
#                request       0.86      0.41      0.56       728
#
#            avg / total       0.92      0.93      0.92      6554
#  ---
# shelter :
#                         precision    recall  f1-score   support
#
#                related       0.93      1.00      0.96      5971
#                request       0.86      0.24      0.37       583
#
#            avg / total       0.92      0.93      0.91      6554
#  ---
# clothing :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6452
#                request       0.67      0.04      0.07       102
#
#            avg / total       0.98      0.98      0.98      6554
#  ---
# money :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6390
#                request       0.80      0.02      0.05       164
#
#            avg / total       0.97      0.98      0.96      6554
#  ---
# missing_people :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6476
#                request       0.00      0.00      0.00        78
#
#            avg / total       0.98      0.99      0.98      6554
#  ---
# refugees :
#                         precision    recall  f1-score   support
#
#                related       0.97      1.00      0.98      6339
#                request       0.89      0.04      0.07       215
#
#            avg / total       0.97      0.97      0.95      6554
#  ---
# death :
#                         precision    recall  f1-score   support
#
#                related       0.96      1.00      0.98      6226
#                request       0.86      0.11      0.20       328
#
#            avg / total       0.95      0.95      0.94      6554
#  ---
# other_aid :
#                         precision    recall  f1-score   support
#
#                related       0.87      1.00      0.93      5676
#                request       0.57      0.01      0.03       878
#
#            avg / total       0.83      0.87      0.81      6554
#  ---
# infrastructure_related :
#                         precision    recall  f1-score   support
#
#                related       0.94      1.00      0.97      6133
#                request       0.25      0.00      0.00       421
#
#            avg / total       0.89      0.94      0.90      6554
#  ---
# transport :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.98      6229
#                request       0.87      0.08      0.15       325
#
#            avg / total       0.95      0.95      0.94      6554
#  ---
# buildings :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.98      6225
#                request       0.76      0.11      0.19       329
#
#            avg / total       0.95      0.95      0.94      6554
#  ---
# electricity :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6426
#                request       1.00      0.02      0.03       128
#
#            avg / total       0.98      0.98      0.97      6554
#  ---
# tools :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      6514
#                request       0.00      0.00      0.00        40
#
#            avg / total       0.99      0.99      0.99      6554
#  ---
# hospitals :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6477
#                request       0.00      0.00      0.00        77
#
#            avg / total       0.98      0.99      0.98      6554
#  ---
# shops :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      6518
#                request       0.00      0.00      0.00        36
#
#            avg / total       0.99      0.99      0.99      6554
#  ---
# aid_centers :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      0.99      6477
#                request       0.00      0.00      0.00        77
#
#            avg / total       0.98      0.99      0.98      6554
#  ---
# other_infrastructure :
#                         precision    recall  f1-score   support
#
#                related       0.96      1.00      0.98      6284
#                request       0.00      0.00      0.00       270
#
#            avg / total       0.92      0.96      0.94      6554
#  ---
# weather_related :
#                         precision    recall  f1-score   support
#
#                related       0.87      0.96      0.91      4690
#                request       0.86      0.63      0.73      1864
#
#            avg / total       0.87      0.87      0.86      6554
#  ---
# floods :
#                         precision    recall  f1-score   support
#
#                related       0.94      1.00      0.97      5984
#                request       0.95      0.28      0.44       570
#
#            avg / total       0.94      0.94      0.92      6554
#  ---
# storm :
#                         precision    recall  f1-score   support
#
#                related       0.95      0.99      0.97      5955
#                request       0.75      0.45      0.56       599
#
#            avg / total       0.93      0.94      0.93      6554
#  ---
# fire :
#                         precision    recall  f1-score   support
#
#                related       0.99      1.00      1.00      6504
#                request       0.00      0.00      0.00        50
#
#            avg / total       0.98      0.99      0.99      6554
#  ---
# earthquake :
#                         precision    recall  f1-score   support
#
#                related       0.96      0.99      0.97      5911
#                request       0.89      0.58      0.70       643
#
#            avg / total       0.95      0.95      0.95      6554
#  ---
# cold :
#                         precision    recall  f1-score   support
#
#                related       0.98      1.00      0.99      6423
#                request       0.78      0.05      0.10       131
#
#            avg / total       0.98      0.98      0.97      6554
#  ---
# other_weather :
#                         precision    recall  f1-score   support
#
#                related       0.95      1.00      0.97      6230
#                request       0.53      0.02      0.05       324
#
#            avg / total       0.93      0.95      0.93      6554
#  ---
# direct_report :
#                         precision    recall  f1-score   support
#
#                related       0.86      0.98      0.92      5254
#                request       0.85      0.35      0.50      1300
#
#            avg / total       0.86      0.86      0.84      6554
#  ---
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 2, does not match size of target_names, 36
#   .format(len(labels), len(target_names))
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 1, does not match size of target_names, 36
#   .format(len(labels), len(target_names))

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
with open('classifier.pkl', 'wb') as file:
    pickle.dump(new_model, file)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
